# %%
import numpy as np

path = "../FinalDataset/ptt.csv"
ptt = np.genfromtxt(path)
#print("The shape of the sample ptt file is: ", ptt.shape)

rho = 1035 #kg/m3
d = 0.6 #m
h = 0.5 #m
conv_const = 0.07355590658434

#print(np.max(ptt), np.min(ptt))

BP=((1/0.7)*(((1/2)*rho*((d/ptt)**2))+rho*9.81*h))/133.32
for i in range (len(BP)):
    if(BP[i]<=200 and BP[i]>14):
        print(ptt[i], BP[i], '\n')
# Out:
# 0.48 63.06275716857401
#
# 0.48 63.06275716857401
#
# 0.48 63.06275716857401
#
# 0.52 61.78104549677285
#
# 0.496 62.51278149221195
#
# 0.504 62.2572260870402
#
# 0.488 62.78100794012292
#
# 0.48 63.06275716857401
#
# 0.472 63.35895370326625
#
# 0.48 63.06275716857401
#
# 0.576 60.41531050426472
#
# 0.44 64.70970370354627
#
# 0.12 193.0283206892118
#
# 0.584 60.25159235557366
#
# 0.12 193.0283206892118
#
# 0.56 60.76404652127022
#
# 0.272 81.38085620227865
#
# 0.544 61.144003750968274
#
# 0.552 60.94989545538405
#
# 0.256 84.85906521734763
#
# 0.536 61.346868166274355
#
# 0.528 61.55902337577323
#
# 0.232 91.48725100554901
#
# 0.552 60.94989545538405
#
# 0.264 83.04093470149849
#
# 0.272 81.38085620227865
#
# 0.264 83.04093470149849
#
# 0.28 79.86102728348637
#
# 0.28 79.86102728348637
#
# 0.248 86.85596716725337
#
# 0.28 79.86102728348637
#
# 0.568 60.585994925193205
#
# 0.568 60.585994925193205
#
# 0.544 61.144003750968274
#
# 0.424 65.50259959754811
#
# 0.48 63.06275716857401
#
# ...
