# %%
import numpy as np

path = "../FinalDataset/ptt.csv"
ptt = np.genfromtxt(path)
#print("The shape of the sample ptt file is: ", ptt.shape)

rho = 1035 #kg/m3
d = 1.1 #m
h = 1 #m
conv_const = 0.07355590658434

#print(np.max(ptt), np.min(ptt))

BP=((1/0.7)*(((1/2)*rho*((d/ptt)**2))+rho*9.81*h))/133.32
for i in range (len(BP)):
    if(BP[i]<500 and BP[i]>14):
        print(ptt[i], BP[i], '\n')
# Out:
# 0.48 137.91868584179852
#
# 0.48 137.91868584179852
#
# 0.48 137.91868584179852
#
# 0.52 133.6107105004668
#
# 0.496 136.07015648513715
#
# 0.504 135.21120637330984
#
# 0.488 136.97169537950458
#
# 0.48 137.91868584179852
#
# 0.472 138.91423530562523
#
# 0.48 137.91868584179852
#
# 0.576 129.0203234423145
#
# 0.44 143.45425613989974
#
# 0.584 128.47004855365842
#
# 0.56 130.19246394391627
#
# 0.272 199.48785203841692
#
# 0.544 131.46954241040146
#
# 0.552 130.81712286135448
#
# 0.256 211.17849900573205
#
# 0.536 132.15139225073577
#
# 0.528 132.86446948266257
#
# 0.232 233.4565679049645
#
# 0.552 130.81712286135448
#
# 0.264 205.06756032746134
#
# 0.272 199.48785203841692
#
# 0.264 205.06756032746134
#
# 0.28 194.37953817247617
#
# 0.28 194.37953817247617
#
# 0.248 217.89030833735973
#
# 0.28 194.37953817247617
#
# 0.568 129.59401274599082
#
# 0.568 129.59401274599082
#
# 0.544 131.46954241040146
#
# 0.424 146.11926733918372
#
# 0.48 137.91868584179852
#
# 0.48 137.91868584179852
#
# 0.48 137.91868584179852
#
# 0.48 137.91868584179852
#
# 0.48 137.91868584179852
#
# 0.52 133.6107105004668
#
# 0.496 136.07015648513715
#
# 0.504 135.21120637330984
#
# 0.488 136.97169537950458
# /tmp/ipykernel_49783/4289965997.py:14: RuntimeWarning: divide by zero encountered in true_divide
#   BP=((1/0.7)*(((1/2)*rho*((d/ptt)**2))+rho*9.81*h))/133.32
